# %% [markdown]
# #BANDS SPLIT one image
# in questo notebook si implementa il codice per estrarre le 4 bande delle immagini png, ottenute dopo il crop delle imamgini scaricate da Google Earth Pro.
#
#
#
# ---
#
#
#
# ---
#
#
#
# 1.   Google Drive viene montato per poter accedere e salvare i file.
# 2.   L'immagine PNG viene aperta con PIL.Image.open().
# 3.  Le quattro bande vengono estratte usando image.split().
# 4. Si crea automaticamente una cartella in Google Drive per i file elaborati.
# 5. Le immagini delle bande vengono salvate in PNG, formato lossless adatto per conservare i dati senza perdita di qualità.
#
#
# ---
#
#
#
# ---

# %%
# Import necessari
import os
from PIL import Image
from google.colab import drive

# %%
# 1. Monta Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 2. Specifica il percorso dell'immagine originale
image_path = "/content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/cropped/201812_cropped.png"
# 3. Carica l'immagine
image = Image.open(image_path)

# %%
# 4. Estrai le bande (Red, Green, Blue, Alpha)
r, g, b, a = image.split()

# %%
# 5. Crea il nome della cartella per salvare le bande
image_name = os.path.basename(image_path).split(".")[0]  # "201901_cropped"
output_folder = f"/content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/{image_name}_bands"
os.makedirs(output_folder, exist_ok=True)  # Crea la cartella se non esiste

# 6. Salva le bande in formato PNG
r.save(os.path.join(output_folder, f"{image_name}_red.png"))
g.save(os.path.join(output_folder, f"{image_name}_green.png"))
b.save(os.path.join(output_folder, f"{image_name}_blue.png"))
#a.save(os.path.join(output_folder, f"{image_name}_alpha.png"))

print(f"Le bande sono state salvate nella cartella: {output_folder}")
# Out:
# Le bande sono state salvate nella cartella: /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201812_cropped_bands

# %% [markdown]
# #BANDS SPLIT function

# %% [markdown]
# Funzione: extract_and_save_bands
# Questa funzione:
#
# Accetta il percorso di una cartella in Google Drive contenente le immagini PNG.
# Per ogni immagine nella cartella:
# Estrae le bande (Rosso, Verde, Blu, Alfa).
# Crea una cartella separata per ogni immagine.
# Salva le quattro bande in formato PNG nella rispettiva cartella.
#
# ---
#
#
#
# ---
#
#
# Crea una cartella in Google Drive con le immagini PNG che vuoi elaborare.
# Aggiorna i percorsi in input_folder e output_folder con i tuoi percorsi reali.
# Esegui il codice in Google Colab.
# Le bande saranno salvate in sottocartelle separate, una per ogni immagine elaborata.
#
#
# ---
#
#
#
# ---

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
from PIL import Image

# %%
# Specificare il percorso della cartella con le immagini su Google Drive
input_folder = "/content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/cropped"

# Specificare il percorso della cartella in cui salvare i risultati
output_base_folder = "/content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands"

# Creare la cartella di output se non esiste
os.makedirs(output_base_folder, exist_ok=True)

# %%
def extract_and_save_bands(image_path, image_name, output_base_folder):
    try:
        # Carica l'immagine
        image = Image.open(image_path)

        # Estrai le bande (Rosso, Verde, Blu, Alfa)
        r, g, b, a = image.split()

        # Crea il nome della cartella per salvare le bande
        image_name = image_name.split('.')[0] # Rimuove ".png"
        output_folder = os.path.join(output_base_folder, f"{image_name}_bands")
        os.makedirs(output_folder, exist_ok=True)

        # Salva le bande in PNG
        r.save(os.path.join(output_folder, f"{image_name}_red.png"))
        g.save(os.path.join(output_folder, f"{image_name}_green.png"))
        b.save(os.path.join(output_folder, f"{image_name}_blue.png"))
        #a.save(os.path.join(output_folder, f"{image_name}_alpha.png"))

        print(f"Elaborata: {image_name} -> Bande salvate in {output_folder}")

    except Exception as e:
        print(f"Errore con {image_name}: {e}")

# %%
# Ottenere la lista delle immagini nella cartella
image_files = [f for f in os.listdir(input_folder) if f.endswith((".png"))]

# Elaborare tutte le immagini
for image_file in image_files:
    image_path = os.path.join(input_folder, image_file)
    extract_and_save_bands(image_path, image_file, output_base_folder)
# Out:
# Elaborata: 201201_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201201_cropped_bands
# Elaborata: 201209_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201209_cropped_bands
# Elaborata: 201306_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201306_cropped_bands
# Elaborata: 201310_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201310_cropped_bands
# Elaborata: 201401_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201401_cropped_bands
# Elaborata: 201405_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201405_cropped_bands
# Elaborata: 201410_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201410_cropped_bands
# Elaborata: 20141201_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/20141201_cropped_bands
# Elaborata: 20150101_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/20150101_cropped_bands
# Elaborata: 20150201_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/20150201_cropped_bands
# Elaborata: 201503_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201503_cropped_bands
# Elaborata: 20150901_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/20150901_cropped_bands
# Elaborata: 201701_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201701_cropped_bands
# Elaborata: 20171201_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/20171201_cropped_bands
# Elaborata: 201712_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201712_cropped_bands
# Elaborata: 201812_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201812_cropped_bands
# Elaborata: 20190201_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/20190201_cropped_bands
# Elaborata: 201909_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201909_cropped_bands
# Elaborata: 202001_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202001_cropped_bands
# Elaborata: 202101_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202101_cropped_bands
# Elaborata: 202108_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202108_cropped_bands
# Elaborata: 202203_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202203_cropped_bands
# Elaborata: 202402_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202402_cropped_bands
# Elaborata: 201303_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201303_cropped_bands
# Elaborata: 201309_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201309_cropped_bands
# Elaborata: 201312_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201312_cropped_bands
# Elaborata: 201403_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201403_cropped_bands
# Elaborata: 201409_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201409_cropped_bands
# Elaborata: 201411_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201411_cropped_bands
# Elaborata: 201412_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201412_cropped_bands
# Elaborata: 201501_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201501_cropped_bands
# Elaborata: 201502_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201502_cropped_bands
# Elaborata: 201506_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201506_cropped_bands
# Elaborata: 201509_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201509_cropped_bands
# Elaborata: 201703_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201703_cropped_bands
# Elaborata: 20171202_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/20171202_cropped_bands
# Elaborata: 201808_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201808_cropped_bands
# Elaborata: 201901_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201901_cropped_bands
# Elaborata: 201902_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201902_cropped_bands
# Elaborata: 201903_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201903_cropped_bands
# Elaborata: 201908_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/201908_cropped_bands
# Elaborata: 202010_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202010_cropped_bands
# Elaborata: 202102_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202102_cropped_bands
# Elaborata: 202201_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202201_cropped_bands
# Elaborata: 202301_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202301_cropped_bands
# Elaborata: 202501_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/202501_cropped_bands
# Elaborata: 20190202_cropped -> Bande salvate in /content/drive/MyDrive/Colab Notebooks/Mat4Pat/GEP/Kenya/bands/20190202_cropped_bands
