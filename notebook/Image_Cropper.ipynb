# %% [markdown]
# #Cropp di immagini satellitari in formato jpg

# %% [markdown]
# In questo notebook, data un'immagine jpg e date le 4 coordinate pixel, si ritaglia l'immagine al solo riquadro di interesse.
# Per selezionare i 4 vertici del poligono da ritagliare si utilizza lo script python "seleziona_punti.py".

# %%
from PIL import Image, ImageDraw
import os

# %%
# Punti del poligono (in ordine)
#P1 = (1930, 435)
#P2 = (5297, 435)
#P3 = (5297, 4474)
#P4 = (1930, 4474)

P1 = (305, 594)
P2 = (1954, 594)
P3 = (1954, 1262)
P4 = (305, 1262)

'''
P1 = (2550, 170)
P2 = (6200, 170)
P3 = (6200, 4270)
P4 = (2550, 4270)'''


polygon_points = [P1, P2, P3, P4]  # Assicurati che siano in ordine (antiorario o orario)

# %%
# Definisci la funzione per ritagliare un'immagine in base ai punti del poligono
def crop_image_with_polygon(image_path, points, output_dir):
    # Carica l'immagine
    image = Image.open(image_path)

    # Creare una maschera con lo stesso formato e dimensione dell'immagine
    mask = Image.new("L", image.size, 0)  # 'L' significa scala di grigi (0-255)
    draw = ImageDraw.Draw(mask)
    draw.polygon(points, fill=255)  # Disegna il poligono e riempilo con bianco (255)

    # Applica la maschera all'immagine originale
    result = Image.new("RGBA", image.size)  # Creare un'immagine con canale alpha
    result.paste(image, mask=mask)  # Applica la maschera per conservare solo il poligono

    # Ritaglia l'immagine al bounding box del poligono per risparmiare spazio
    x_coords, y_coords = zip(*points)
    x_min, x_max = min(x_coords), max(x_coords)
    y_min, y_max = min(y_coords), max(y_coords)
    result_cropped = result.crop((x_min, y_min, x_max, y_max))

    # Salva l'immagine ritagliata
    image_name = os.path.basename(image_path).split('.')[0]
    output_path = os.path.join(output_dir, f"{image_name}_cropped.png")
    result_cropped.save(output_path)
    print(f"Immagine salvata: {output_path}")

# %%
import google.colab.drive
google.colab.drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Specifica la directory delle immagini e la directory di output
input_dir = "/content/Kenya/"
output_dir = "/content/cropped_images"
os.makedirs(output_dir, exist_ok=True)

# %%
# Itera attraverso tutte le immagini nella directory

for filename in os.listdir(input_dir):
    if filename.lower().endswith(('.jpg')):  # Filtra per immagini jpg
        image_path = os.path.join(input_dir, filename)
        crop_image_with_polygon(image_path, polygon_points, output_dir)

print("Elaborazione completata!")
# Out:
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/0_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/1_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/2_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/3_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/4_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/5_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/6_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/7_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/8_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/9_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/10_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/11_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/12_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/13_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/14_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/15_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/16_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/17_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/18_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/19_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/20_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/21_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/22_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/23_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/24_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/25_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/26_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/27_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/28_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/29_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/30_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/31_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/32_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/33_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/34_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/35_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/36_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/37_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/38_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/39_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/40_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/41_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/42_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/43_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/44_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/45_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/46_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/47_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/48_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/49_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/50_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/51_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/52_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/53_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/54_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/55_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/56_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/57_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/58_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/59_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/60_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/61_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/62_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/63_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/64_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/65_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/66_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/67_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/68_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/69_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/70_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/71_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/72_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/73_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/74_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/75_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/76_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/77_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/78_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/79_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/80_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/81_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/82_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/83_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/84_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/85_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/86_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/87_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/88_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/89_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/90_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/91_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/92_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/93_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/94_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/95_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/96_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/97_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/98_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/99_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/100_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/101_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/102_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/103_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/104_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/105_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/106_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/107_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/108_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/109_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/110_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/111_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/112_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/113_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/114_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/115_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/116_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/117_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/118_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/119_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/120_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/121_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/122_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/123_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/124_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/125_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/126_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/127_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/128_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/129_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/130_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/131_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/132_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/133_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/134_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/135_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/136_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/137_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/138_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/139_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/140_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/141_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/142_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/143_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/144_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/145_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/146_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/147_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/148_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/149_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/150_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/151_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/152_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/153_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/154_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/155_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/156_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/157_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/158_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/159_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/160_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/161_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/162_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/163_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/164_cropped.png
# Immagine salvata: /content/drive/MyDrive/Astronomia Generale/risposte_corrette_cropped/165_cropped.png
# Elaborazione completata!
